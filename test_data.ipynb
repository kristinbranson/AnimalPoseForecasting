# %%
# Out:
# 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure()
x = np.arange(0, np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
import open3d

sphere = open3d.geometries.TriangleMesh.create_sphere(1, 10)
open3d.visualization.draw_geometries([sphere])
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 import open3d
# ----> 3 sphere = open3d.geometries.TriangleMesh.create_sphere(1, 10)
#       4 open3d.visualization.draw_geometries([sphere])
#
# AttributeError: module 'open3d' has no attribute 'geometries'

# %%
sphere
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sphere
#
# NameError: name 'sphere' is not defined

# %%
1+1
# Out:
# 2
